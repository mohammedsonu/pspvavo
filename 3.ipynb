# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print("before swapping a=%d b=%d" %(a,b))
temp=a
a=b
b=temp
print("after swapping a=%d b=%d" %(a,b))
# Out:
# Enter the first number24
# Enter the second number23
# before swapping a=24 b=23
# after swapping a=23 b=24

# %%
a=int(input("enter the first number"))
b=int(input( "enter the second number"))
sum=a+b
print(sum)
# Out:
# enter the first number35
# enter the second number44
# 79

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a if a>=b else b)
# Out:
# Enter the first number24
# Enter the second number55
# 55

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
if(a>b):
  print("%d is greater"%(a))
else:
   print("%d is greatest"%(b))
# Out:
# Enter the first number67
# Enter the second number98
# 98 is greatest

# %%
r=int(input("Enter the radius of circle."))
pi=3.14
Area=pi*r*r
print("%d is the area of given circle" % (Area))
# Out:
# Enter the radius of circle.66
# 13677 is the area of given circle

# %%
r=int(input("Enter the radius of circle"))
pi=3.14
circumference=2*pi*r
print("%d is the circumference of given circle" % (circumference))
# Out:
# Enter the radius of circle44
# 276 is the circumference of given circle

# %%
Age=int(input("Enter age."))
if(Age>=18):
  print("Person is eligible to vote.")
else:
   print("person is not eligible to vote")
# Out:
# Enter age.42
# Person is eligible to vote.

# %%
basic=int(input("Enter Basic Salary"))
DA=int(input("Enter current DA"))
HRA=24
Transport=200
Others=50
Salary=basic+basic*DA/100+Transport+Others
print("%d is the employee's salary" %(Salary))
# Out:
# Enter Basic Salary20000
# Enter current DA45
# 29250 is the employee's salary

# %%
a=int(input("Enter year"))
if("a is a leap year"):
  print("%d is a leap year" % (a))
# Out:
# Enter year2032
# 2032 is a leap year
