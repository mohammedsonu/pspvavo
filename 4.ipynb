# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print("before swapping a=%d b=d%" %(a,b))
temp=a
a=b
b=temp
print("after swapping a=%d b=d%" %(a,b))
# Out:
# Enter the first number35
# Enter the second number53
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9d9381caa426> in <cell line: 3>()
#       1 a=int(input("Enter the first number"))
#       2 b=int(input("Enter the second number"))
# ----> 3 print("before swapping a=%d b=d%" %(a,b))
#       4 temp=a
#       5 a=b
#
# ValueError: incomplete format
